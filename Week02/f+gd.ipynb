# %%
def gradient_descent_update(x, gradx, learning_rate):
    """
    Performs a gradient descent update.
    """
    # TODO: Implement gradient descent.
    
    # Return the new value for x
    x = x - learning_rate * gradx
    return x
# import f


"""
Given the starting point of any `x` gradient descent
should be able to find the minimum value of x for the
cost function `f` defined below.
"""
import random
# from gd import gradient_descent_update


def f(x):
    """
    Quadratic function.

    It's easy to see the minimum value of the function
    is 5 when is x=0.
    """
    return x**2 + 5


def df(x):
    """
    Derivative of `f` with respect to `x`.
    """
    return 2*x


# Random number better 0 and 10,000. Feel free to set x whatever you like.
x = random.randint(0, 10000)
# TODO: Set the learning rate
learning_rate = 0.1
epochs = 100

for i in range(epochs+1):
    cost = f(x)
    gradx = df(x)
    print("EPOCH {}: Cost = {:.3f}, x = {:.3f}".format(i, cost, gradx))
    x = gradient_descent_update(x, gradx, learning_rate)
# Out:
# EPOCH 0: Cost = 1532649.000, x = 2476.000
# EPOCH 1: Cost = 980897.160, x = 1980.800
# EPOCH 2: Cost = 627775.982, x = 1584.640
# EPOCH 3: Cost = 401778.429, x = 1267.712
# EPOCH 4: Cost = 257139.994, x = 1014.170
# EPOCH 5: Cost = 164571.396, x = 811.336
# EPOCH 6: Cost = 105327.494, x = 649.069
# EPOCH 7: Cost = 67411.396, x = 519.255
# EPOCH 8: Cost = 43145.093, x = 415.404
# EPOCH 9: Cost = 27614.660, x = 332.323
# EPOCH 10: Cost = 17675.182, x = 265.858
# EPOCH 11: Cost = 11313.917, x = 212.687
# EPOCH 12: Cost = 7242.707, x = 170.149
# EPOCH 13: Cost = 4637.132, x = 136.120
# EPOCH 14: Cost = 2969.565, x = 108.896
# EPOCH 15: Cost = 1902.321, x = 87.117
# EPOCH 16: Cost = 1219.286, x = 69.693
# EPOCH 17: Cost = 782.143, x = 55.755
# EPOCH 18: Cost = 502.371, x = 44.604
# EPOCH 19: Cost = 323.318, x = 35.683
# EPOCH 20: Cost = 208.723, x = 28.546
# EPOCH 21: Cost = 135.383, x = 22.837
# EPOCH 22: Cost = 88.445, x = 18.270
# EPOCH 23: Cost = 58.405, x = 14.616
# EPOCH 24: Cost = 39.179, x = 11.693
# EPOCH 25: Cost = 26.875, x = 9.354
# EPOCH 26: Cost = 19.000, x = 7.483
# EPOCH 27: Cost = 13.960, x = 5.987
# EPOCH 28: Cost = 10.734, x = 4.789
# EPOCH 29: Cost = 8.670, x = 3.831
# EPOCH 30: Cost = 7.349, x = 3.065
# EPOCH 31: Cost = 6.503, x = 2.452
# EPOCH 32: Cost = 5.962, x = 1.962
# EPOCH 33: Cost = 5.616, x = 1.569
# EPOCH 34: Cost = 5.394, x = 1.255
# EPOCH 35: Cost = 5.252, x = 1.004
# EPOCH 36: Cost = 5.161, x = 0.804
# EPOCH 37: Cost = 5.103, x = 0.643
# EPOCH 38: Cost = 5.066, x = 0.514
# EPOCH 39: Cost = 5.042, x = 0.411
# EPOCH 40: Cost = 5.027, x = 0.329
# EPOCH 41: Cost = 5.017, x = 0.263
# EPOCH 42: Cost = 5.011, x = 0.211
# EPOCH 43: Cost = 5.007, x = 0.169
# EPOCH 44: Cost = 5.005, x = 0.135
# EPOCH 45: Cost = 5.003, x = 0.108
# EPOCH 46: Cost = 5.002, x = 0.086
# EPOCH 47: Cost = 5.001, x = 0.069
# EPOCH 48: Cost = 5.001, x = 0.055
# EPOCH 49: Cost = 5.000, x = 0.044
# EPOCH 50: Cost = 5.000, x = 0.035
# EPOCH 51: Cost = 5.000, x = 0.028
# EPOCH 52: Cost = 5.000, x = 0.023
# EPOCH 53: Cost = 5.000, x = 0.018
# EPOCH 54: Cost = 5.000, x = 0.014
# EPOCH 55: Cost = 5.000, x = 0.012
# EPOCH 56: Cost = 5.000, x = 0.009
# EPOCH 57: Cost = 5.000, x = 0.007
# EPOCH 58: Cost = 5.000, x = 0.006
# EPOCH 59: Cost = 5.000, x = 0.005
# EPOCH 60: Cost = 5.000, x = 0.004
# EPOCH 61: Cost = 5.000, x = 0.003
# EPOCH 62: Cost = 5.000, x = 0.002
# EPOCH 63: Cost = 5.000, x = 0.002
# EPOCH 64: Cost = 5.000, x = 0.002
# EPOCH 65: Cost = 5.000, x = 0.001
# EPOCH 66: Cost = 5.000, x = 0.001
# EPOCH 67: Cost = 5.000, x = 0.001
# EPOCH 68: Cost = 5.000, x = 0.001
# EPOCH 69: Cost = 5.000, x = 0.001
# EPOCH 70: Cost = 5.000, x = 0.000
# EPOCH 71: Cost = 5.000, x = 0.000
# EPOCH 72: Cost = 5.000, x = 0.000
# EPOCH 73: Cost = 5.000, x = 0.000
# EPOCH 74: Cost = 5.000, x = 0.000
# EPOCH 75: Cost = 5.000, x = 0.000
# EPOCH 76: Cost = 5.000, x = 0.000
# EPOCH 77: Cost = 5.000, x = 0.000
# EPOCH 78: Cost = 5.000, x = 0.000
# EPOCH 79: Cost = 5.000, x = 0.000
# EPOCH 80: Cost = 5.000, x = 0.000
# EPOCH 81: Cost = 5.000, x = 0.000
# EPOCH 82: Cost = 5.000, x = 0.000
# EPOCH 83: Cost = 5.000, x = 0.000
# EPOCH 84: Cost = 5.000, x = 0.000
# EPOCH 85: Cost = 5.000, x = 0.000
# EPOCH 86: Cost = 5.000, x = 0.000
# EPOCH 87: Cost = 5.000, x = 0.000
# EPOCH 88: Cost = 5.000, x = 0.000
# EPOCH 89: Cost = 5.000, x = 0.000
# EPOCH 90: Cost = 5.000, x = 0.000
# EPOCH 91: Cost = 5.000, x = 0.000
# EPOCH 92: Cost = 5.000, x = 0.000
# EPOCH 93: Cost = 5.000, x = 0.000
# EPOCH 94: Cost = 5.000, x = 0.000
# EPOCH 95: Cost = 5.000, x = 0.000
# EPOCH 96: Cost = 5.000, x = 0.000
# EPOCH 97: Cost = 5.000, x = 0.000
# EPOCH 98: Cost = 5.000, x = 0.000
# EPOCH 99: Cost = 5.000, x = 0.000
# EPOCH 100: Cost = 5.000, x = 0.000
