# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
prob_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts} 

train_words = [word for word in int_words if prob_drop[word] < random.random()]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    # Your code here
    R = np.random.randint(1, window_size+1)
    a = idx - R if (idx - R) > 0 else 0 
    b = idx + R  
    return words[a : idx] + words[idx+1: b + 1]

get_target( ['a','b','c','d','e','f','g',1,2,3,4,5,6,7,8,9], idx=2)
# Out:
# ['a', 'b', 'd', 'e']

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform). This [TensorFlow tutorial](https://www.tensorflow.org/tutorials/word2vec) will help if you get stuck.

# %%
n_vocab = len(int_to_vocab)
n_embedding = 100 # Number of embedding features 
with train_graph.as_default():
    # create embedding weight matrix here
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1.0, 1.0)) 
    # use tf.nn.embedding_lookup to get the hidden layer output
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    # create softmax weight matrix here
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.4695 0.5232 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.4512 0.4419 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.3435 0.4116 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.4433 0.4828 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.3689 0.4829 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.3402 0.5202 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.4087 0.5142 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.4176 0.5188 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.3112 0.5203 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.2653 0.5199 sec/batch
# Nearest to some: aggrieved, mcmanus, market, genealogies, heralding, jade, rijeka, bharat,
# Nearest to new: flocking, czechoslovakian, anesthesia, taxable, marcus, disagrees, grossing, omb,
# Nearest to after: balloon, gere, cigars, affects, notably, byzantines, communiqu, advantage,
# Nearest to and: specializes, maths, manutius, trappers, humber, hyi, labels, whore,
# Nearest to first: guaranteeing, extensive, paraphilia, differentiability, hulagu, silky, sustained, huntingford,
# Nearest to when: exquisite, elke, dimensions, auntie, hitters, newstead, farmer, masoch,
# Nearest to by: indirection, postponed, cardigan, tabula, stockade, excluding, grievances, dhimma,
# Nearest to however: bono, bayqongyr, rabbani, impressive, mathematically, infrastructures, splitter, ilyich,
# Nearest to centre: defensa, therapeutics, beginnings, adornment, radiometric, unsophisticated, walruses, kidneys,
# Nearest to pre: iranic, hoffman, underwear, carotene, metaphase, surrealist, yao, fabrique,
# Nearest to report: risorgimento, bismarck, metafont, dalida, scouts, sham, louis, crafty,
# Nearest to scale: amidst, neoplatonist, wankel, terrorizing, elevation, hibiscus, bombardier, wilhelms,
# Nearest to powers: ilr, valeria, gosh, deems, marital, sculptor, grit, luxury,
# Nearest to channel: blockers, theodosian, centipede, gog, baptized, javan, acceding, gere,
# Nearest to egypt: circulation, climate, norville, kraepelin, sopra, tagore, interferon, xxxg,
# Nearest to joseph: distrusted, tura, decimalisation, coppa, layton, malan, pinsent, cornwall,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4024 0.5222 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3236 0.5184 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.2723 0.5183 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2125 0.5140 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1397 0.5182 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1497 0.5186 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0888 0.5150 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0268 0.5075 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.9705 0.4930 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9817 0.4888 sec/batch
# Nearest to some: market, moved, may, treaty, original, between, jesus, enclaves,
# Nearest to new: tenth, sometimes, casual, links, grossing, marcus, stan, and,
# Nearest to after: notably, advantage, wait, affects, balloon, designed, july, architecture,
# Nearest to and: specializes, not, often, being, sources, maths, seen, humber,
# Nearest to first: sacrifices, extensive, paraphilia, wish, sustained, document, asserts, tahitian,
# Nearest to when: dimensions, will, husband, majority, now, masoch, optional, productivity,
# Nearest to by: detailed, lack, excluding, sampled, lacoste, cruelty, stockade, satirizing,
# Nearest to however: impressive, coerced, iconoclasm, labeled, often, schaffner, directed, uniformly,
# Nearest to centre: beginnings, defensa, radiometric, unsophisticated, ought, therapeutics, kidneys, sweethearts,
# Nearest to pre: iranic, hoffman, john, lesser, malayan, lys, disappearance, underwear,
# Nearest to report: louis, sham, risorgimento, africa, path, bismarck, births, presidency,
# Nearest to scale: amidst, elevation, inflation, frequent, presence, symbolic, bicyclists, quarterfinals,
# Nearest to powers: ilr, valeria, impairs, cannot, marital, sarah, ve, sans,
# Nearest to channel: blockers, javan, fleeting, baptized, indicated, theodosian, gog, raping,
# Nearest to egypt: circulation, climate, norville, interferon, tagore, sopra, kraepelin, eurydice,
# Nearest to joseph: distrusted, decimalisation, coppa, retrospective, that, economically, layton, systran,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9398 0.4935 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8831 0.4923 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8476 0.4908 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8592 0.4900 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.7791 0.4900 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.7991 0.4899 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7653 0.4896 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7572 0.4913 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7605 0.4909 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7481 0.4898 sec/batch
# Nearest to some: jesus, treaty, market, between, moved, may, genealogies, aggrieved,
# Nearest to new: grossing, tenth, stan, heard, molecules, links, impede, marcus,
# Nearest to after: july, notably, affects, balloon, advantage, had, debate, son,
# Nearest to and: specializes, contact, labels, maths, sources, often, manutius, toward,
# Nearest to first: extensive, sustained, equals, viking, wish, sacrifices, guaranteeing, asserts,
# Nearest to when: dimensions, majority, will, farmer, participated, massive, exquisite, optional,
# Nearest to by: excluding, detailed, payoff, postponed, shifted, contentious, except, satirizing,
# Nearest to however: impressive, mathematically, labeled, peace, debate, often, iconoclasm, tag,
# Nearest to centre: beginnings, ought, defensa, unsophisticated, radiometric, shallow, therapeutics, kidneys,
# Nearest to pre: iranic, hoffman, lesser, john, disappearance, malayan, enjoy, widely,
# Nearest to report: presidency, bismarck, louis, sham, scouts, risorgimento, contemporaries, sermon,
# Nearest to scale: amidst, elevation, inflation, disaster, symbolic, frequent, presence, contrary,
# Nearest to powers: impairs, valeria, cannot, ve, ilr, marital, sans, sarah,
# Nearest to channel: blockers, indicated, fleeting, javan, baptized, into, raping, cobol,
# Nearest to egypt: circulation, climate, norville, ferdinand, interferon, sopra, tagore, chance,
# Nearest to joseph: distrusted, economically, becoming, decimalisation, that, systran, retrospective, shrinking,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7222 0.4305 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7102 0.4368 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.6857 0.4242 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.6819 0.4263 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7199 0.4253 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7158 0.4262 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6674 0.4268 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7088 0.4274 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6844 0.4244 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6658 0.4266 sec/batch
# Nearest to some: jesus, jade, between, enclaves, aggrieved, accomplish, may, treaty,
# Nearest to new: grossing, tenth, scandal, stan, czechoslovakian, marcus, heard, and,
# Nearest to after: july, had, affects, notably, balloon, gains, son, eventually,
# Nearest to and: labels, maths, contact, manutius, specializes, bankrupt, maximus, madhya,
# Nearest to first: extensive, guaranteeing, sustained, equals, viking, hulagu, paraphilia, huntingford,
# Nearest to when: exquisite, dimensions, farmer, majority, massive, disappointed, will, await,
# Nearest to by: excluding, postponed, shifted, payoff, grievances, contentious, satirizing, juan,
# Nearest to however: impressive, mathematically, bono, iconoclasm, geodetic, commandos, peace, scrolling,
# Nearest to centre: beginnings, defensa, courtesy, acadia, newspaper, therapeutics, unsophisticated, radiometric,
# Nearest to pre: iranic, lesser, hoffman, disappearance, malayan, surrealist, yao, enjoy,
# Nearest to report: presidency, bismarck, louis, risorgimento, sham, arctic, embarrassment, dalida,
# Nearest to scale: amidst, disaster, elevation, inflation, bicyclists, neoplatonist, quarterfinals, contradictory,
# Nearest to powers: ilr, valeria, impairs, sarah, marital, ve, luxury, sans,
# Nearest to channel: javan, blockers, fleeting, baptized, indicated, raping, cobol, ppm,
# Nearest to egypt: circulation, climate, ferdinand, interferon, norville, sopra, tagore, latvia,
# Nearest to joseph: distrusted, accuser, becoming, systran, lachmann, economically, cornwall, decimalisation,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6772 0.4498 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6406 0.4381 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.5933 0.4377 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6077 0.4381 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6399 0.4403 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6195 0.4387 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6309 0.3145 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5787 0.4378 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5516 0.4382 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5482 0.4370 sec/batch
# Nearest to some: jesus, jade, clinicians, may, between, proposer, topic, physical,
# Nearest to new: grossing, tenth, czechoslovakian, and, scandal, byron, kai, stan,
# Nearest to after: had, gere, july, byzantines, son, balloon, veered, pseudalopex,
# Nearest to and: labels, madhya, maximus, new, bankrupt, maths, technologically, manutius,
# Nearest to first: guaranteeing, extensive, sustained, equals, hulagu, skeletons, viking, huntingford,
# Nearest to when: exquisite, farmer, dimensions, disappointed, will, await, standardise, massive,
# Nearest to by: postponed, excluding, shifted, tabula, indirection, satirizing, grievances, pastoral,
# Nearest to however: impressive, mathematically, scrolling, iconoclasm, bono, geodetic, commandos, hacks,
# Nearest to centre: beginnings, defensa, courtesy, landsat, acadia, newspaper, futuristic, ought,
# Nearest to pre: iranic, lesser, hoffman, disappearance, surrealist, malayan, consolidation, yao,
# Nearest to report: bismarck, presidency, sham, risorgimento, louis, embarrassment, dalida, crafty,
# Nearest to scale: amidst, elevation, bicyclists, disaster, curvature, inflation, kvac, contradictory,
# Nearest to powers: ilr, valeria, sarah, ve, impairs, marital, luxury, exams,
# Nearest to channel: javan, fleeting, blockers, gog, baptized, raping, into, ppm,
# Nearest to egypt: circulation, interferon, sopra, tagore, climate, norville, hydroxyl, ferdinand,
# Nearest to joseph: accuser, distrusted, lachmann, systran, deaths, becoming, tippett, germany,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5212 0.4423 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5060 0.4370 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.5344 0.4361 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5625 0.4378 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.5449 0.4365 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.5237 0.4379 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.5152 0.4388 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4481 0.4374 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4783 0.4379 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4807 0.4344 sec/batch
# Nearest to some: jesus, may, clinicians, between, jade, physical, that, proposer,
# Nearest to new: grossing, scandal, czechoslovakian, byron, kai, and, tenth, links,
# Nearest to after: had, byzantines, july, gere, son, eventually, veered, leader,
# Nearest to and: madhya, simulate, labels, manutius, technologically, contact, new, rationalization,
# Nearest to first: extensive, guaranteeing, equals, sustained, huntingford, skeletons, greenland, aztec,
# Nearest to when: exquisite, will, standardise, farmer, dimensions, would, massive, await,
# Nearest to by: excluding, postponed, tabula, fart, indirection, pastoral, shifted, stockade,
# Nearest to however: impressive, iconoclasm, mathematically, scrolling, bono, infrastructures, debate, chlorine,
# Nearest to centre: beginnings, defensa, landsat, acadia, futuristic, courtesy, newspaper, located,
# Nearest to pre: iranic, lesser, hoffman, disappearance, surrealist, consolidation, malayan, unbound,
# Nearest to report: bismarck, presidency, sham, oeuvre, risorgimento, dalida, embarrassment, venona,
# Nearest to scale: amidst, curvature, bicyclists, elevation, disaster, kvac, colliding, inflation,
# Nearest to powers: ilr, valeria, sarah, luxury, impairs, marital, daimler, ve,
# Nearest to channel: javan, gog, fleeting, blockers, psyche, into, detectable, grafton,
# Nearest to egypt: interferon, sopra, circulation, municipality, utrecht, climate, norville, tagore,
# Nearest to joseph: accuser, distrusted, lachmann, deaths, decimalisation, tippett, becoming, cornwall,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.5071 0.4431 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4562 0.4392 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4693 0.4360 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4651 0.4376 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4573 0.4379 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4690 0.4365 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.4537 0.4374 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.4597 0.4369 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4683 0.4376 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.4211 0.4386 sec/batch
# Nearest to some: may, clinicians, jesus, between, physical, that, jade, genealogies,
# Nearest to new: grossing, scandal, czechoslovakian, byron, and, wed, tenth, bolton,
# Nearest to after: had, byzantines, july, gere, veered, leader, exile, son,
# Nearest to and: bankrupt, manutius, simulate, labels, madhya, contact, new, rationalization,
# Nearest to first: huntingford, extensive, guaranteeing, equals, titles, aztec, sustained, skeletons,
# Nearest to when: will, exquisite, would, standardise, dimensions, cacti, optional, massive,
# Nearest to by: postponed, excluding, relaying, rooftops, indirection, been, eigenvalue, fart,
# Nearest to however: impressive, scrolling, iconoclasm, bono, mathematically, chlorine, deploying, metabolites,
# Nearest to centre: beginnings, defensa, landsat, acadia, located, futuristic, newspaper, foothills,
# Nearest to pre: iranic, lesser, disappearance, consolidation, unbound, hoffman, surrealist, malayan,
# Nearest to report: bismarck, oeuvre, sham, dalida, risorgimento, presidency, diminished, crafty,
# Nearest to scale: curvature, bicyclists, amidst, elevation, disaster, colliding, kvac, inflation,
# Nearest to powers: ilr, valeria, fiefs, luxury, commanding, marital, ve, sarah,
# Nearest to channel: gog, javan, fleeting, blockers, skynyrd, psyche, detectable, rectifier,
# Nearest to egypt: interferon, sopra, conquered, utrecht, circulation, antilles, municipality, climate,
# Nearest to joseph: accuser, distrusted, lachmann, deaths, tippett, kenneth, decimalisation, tales,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.4113 0.4429 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.4397 0.4372 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.4100 0.4385 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.4208 0.4387 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4497 0.4474 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.4259 0.4378 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.4325 0.4381 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.4363 0.4392 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3927 0.4376 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.4086 0.4368 sec/batch
# Nearest to some: clinicians, between, may, jesus, physical, writings, exceptions, semiology,
# Nearest to new: grossing, scandal, and, czechoslovakian, byron, alois, bolton, tenth,
# Nearest to after: had, byzantines, july, gere, exile, son, leader, veered,
# Nearest to and: manutius, madhya, rationalization, bankrupt, new, as, labels, hatton,
# Nearest to first: titles, guaranteeing, extensive, huntingford, equals, aztec, greenland, goalscorer,
# Nearest to when: will, exquisite, would, standardise, massive, cacti, optional, farmer,
# Nearest to by: postponed, excluding, indirection, rooftops, fart, been, relaying, shifted,
# Nearest to however: iconoclasm, scrolling, debate, impressive, bono, infrastructures, deploying, chlorine,
# Nearest to centre: beginnings, defensa, landsat, acadia, located, foothills, courtesy, futuristic,
# Nearest to pre: iranic, lesser, unbound, pigmentation, surrealist, consolidation, fabrique, yao,
# Nearest to report: bismarck, oeuvre, diminished, presidency, dalida, risorgimento, sham, louis,
# Nearest to scale: elevation, curvature, amidst, bicyclists, colliding, disaster, temperatures, inflation,
# Nearest to powers: ilr, valeria, fiefs, commanding, dismissed, briefs, secured, daimler,
# Nearest to channel: gog, javan, fleeting, blockers, centipede, rectifier, dana, into,
# Nearest to egypt: sopra, utrecht, conquered, interferon, antilles, circulation, armies, municipality,
# Nearest to joseph: accuser, distrusted, lachmann, kenneth, deaths, tippett, decimalisation, malan,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3795 0.4443 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3662 0.4370 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.4245 0.4382 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.4174 0.4403 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.4334 0.4374 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.3436 0.4376 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3756 0.4386 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.4164 0.4393 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.3039 0.4389 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3547 0.4389 sec/batch
# Nearest to some: between, clinicians, physical, may, exceptions, writings, genealogies, jesus,
# Nearest to new: and, byron, grossing, czechoslovakian, alois, dtm, links, heard,
# Nearest to after: had, byzantines, exile, gere, morning, july, veered, eventually,
# Nearest to and: madhya, rationalization, manutius, new, sighted, bankrupt, zambezi, hatton,
# Nearest to first: titles, guaranteeing, hulagu, rejectionist, extensive, greenland, huntingford, finest,
# Nearest to when: will, would, exquisite, standardise, disappointed, await, onshore, cacti,
# Nearest to by: excluding, postponed, indirection, fart, cardigan, been, rooftops, aqaba,
# Nearest to however: iconoclasm, scrolling, infrastructures, impressive, bono, rabbani, debate, struggle,
# Nearest to centre: beginnings, defensa, landsat, located, acadia, foothills, newspaper, bulgaria,
# Nearest to pre: iranic, lesser, unbound, surrealist, fabrique, pigmentation, metaphase, yao,
# Nearest to report: bismarck, risorgimento, oeuvre, presidency, diminished, fleming, dalida, embarrassment,
# Nearest to scale: curvature, amidst, bicyclists, colliding, elevation, inflation, terrorizing, seabed,
# Nearest to powers: ilr, valeria, fiefs, commanding, secured, dismissed, appointed, briefs,
# Nearest to channel: gog, javan, fleeting, centipede, rectifier, into, detectable, blockers,
# Nearest to egypt: sopra, conquered, utrecht, interferon, antilles, armies, arab, ottoman,
# Nearest to joseph: accuser, lachmann, distrusted, tippett, deaths, kenneth, malan, trintignant,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3443 0.4399 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3532 0.4384 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3987 0.1920 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.3313 0.4373 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2877 0.4391 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2854 0.4381 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2894 0.4385 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2925 0.4382 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.3166 0.4373 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.2488 0.4373 sec/batch
# Nearest to some: clinicians, between, physical, may, semiology, genealogies, exceptions, jade,
# Nearest to new: grossing, czechoslovakian, byron, and, bolton, heard, dtm, scandal,
# Nearest to after: had, byzantines, exile, gere, eventually, morning, wait, july,
# Nearest to and: rationalization, madhya, bankrupt, manutius, sighted, new, differentiated, as,
# Nearest to first: titles, rejectionist, hulagu, equals, greenland, guaranteeing, extensive, huntingford,
# Nearest to when: will, would, exquisite, standardise, onshore, await, they, hitters,
# Nearest to by: postponed, indirection, excluding, fart, aqaba, rooftops, cardigan, been,
# Nearest to however: iconoclasm, bono, scrolling, rabbani, newlyweds, adversely, impressive, infrastructures,
# Nearest to centre: defensa, beginnings, landsat, located, acadia, foothills, lake, shallow,
# Nearest to pre: iranic, lesser, fabrique, unbound, metaphase, yao, culture, surrealist,
# Nearest to report: bismarck, presidency, oeuvre, fleming, risorgimento, sham, diminished, dalida,
# Nearest to scale: curvature, bicyclists, amidst, elevation, colliding, inflation, terrorizing, sewage,
# Nearest to powers: ilr, valeria, commanding, appointed, compromise, secured, fiefs, cabala,
# Nearest to channel: gog, javan, centipede, rectifier, fleeting, dana, detectable, blockers,
# Nearest to egypt: sopra, conquered, utrecht, interferon, zoroastrians, arab, armies, antilles,
# Nearest to joseph: accuser, lachmann, distrusted, tippett, deaths, trintignant, malan, kristin,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.3177 0.4416 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2945 0.4353 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2771 0.4364 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.2118 0.4368 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.2401 0.4370 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.2290 0.4380 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.2361 0.4382 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.2352 0.4381 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2462 0.4371 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.2429 0.4380 sec/batch
# Nearest to some: between, clinicians, physical, may, semiology, exceptions, genealogies, strumming,
# Nearest to new: grossing, and, byron, czechoslovakian, heard, dtm, scandal, alois,
# Nearest to after: had, byzantines, wait, gere, exile, morning, gains, july,
# Nearest to and: rationalization, madhya, as, new, simulate, differentiated, often, manutius,
# Nearest to first: titles, equals, kicks, rejectionist, franke, huntingford, greenland, finest,
# Nearest to when: will, would, exquisite, standardise, they, next, onshore, await,
# Nearest to by: indirection, postponed, rooftops, excluding, eigenvalue, relaying, crystallographic, been,
# Nearest to however: iconoclasm, scrolling, bono, infrastructures, metabolites, rabbani, proportionate, peace,
# Nearest to centre: defensa, landsat, located, beginnings, acadia, foothills, center, lake,
# Nearest to pre: iranic, unbound, lesser, fabrique, culture, surrealist, metaphase, sanctification,
# Nearest to report: bismarck, oeuvre, fleming, presidency, review, diminished, sham, dalida,
# Nearest to scale: bicyclists, curvature, colliding, inflation, amidst, elevation, terrorizing, seabed,
# Nearest to powers: ilr, commanding, valeria, appointed, compromise, fiefs, secured, sihanouk,
# Nearest to channel: javan, gog, rectifier, centipede, dana, subscribers, into, monnet,
# Nearest to egypt: conquered, sopra, arab, interferon, zoroastrians, antilles, utrecht, ottoman,
# Nearest to joseph: accuser, distrusted, lachmann, trintignant, tippett, decimalisation, malan, hackman,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.2046 0.4428 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2606 0.4367 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.2379 0.4371 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.2270 0.4380 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.2331 0.4462 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.2625 0.4373 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2637 0.4385 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1988 0.4387 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1931 0.4394 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.2243 0.4370 sec/batch
# Nearest to some: between, clinicians, genealogies, semiology, exceptions, may, physical, writings,
# Nearest to new: and, grossing, dtm, czechoslovakian, byron, heard, alois, links,
# Nearest to after: had, byzantines, exile, gere, wait, july, morning, veered,
# Nearest to and: rationalization, new, madhya, manutius, as, labels, bankrupt, restraints,
# Nearest to first: titles, equals, kicks, franke, greenland, radius, rejectionist, hulagu,
# Nearest to when: will, exquisite, would, standardise, they, await, onshore, enough,
# Nearest to by: rooftops, indirection, relaying, postponed, gladio, been, excluding, shifted,
# Nearest to however: iconoclasm, scrolling, infrastructures, proportionate, bono, deploying, impressive, consensus,
# Nearest to centre: defensa, located, landsat, beginnings, foothills, acadia, center, lake,
# Nearest to pre: iranic, lesser, unbound, fabrique, metaphase, culture, sanctification, differences,
# Nearest to report: bismarck, review, oeuvre, diminished, fleming, overviews, sham, nsf,
# Nearest to scale: bicyclists, colliding, amidst, terrorizing, curvature, inflation, elevation, letterbox,
# Nearest to powers: commanding, ilr, compromise, appointed, legislation, valeria, fiefs, insurer,
# Nearest to channel: gog, rectifier, dana, javan, subscribers, centipede, lexicography, serial,
# Nearest to egypt: sopra, conquered, arab, antilles, zoroastrians, interferon, utrecht, bouvines,
# Nearest to joseph: accuser, tippett, lachmann, distrusted, trintignant, hackman, kristin, malan,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2701 0.4437 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.2193 0.4401 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.2114 0.4386 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.2370 0.4379 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.2257 0.4379 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1931 0.4381 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.2184 0.4374 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.2068 0.4385 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.2380 0.4392 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2811 0.4399 sec/batch
# Nearest to some: between, genealogies, semiology, clinicians, writings, aggrieved, may, exceptions,
# Nearest to new: and, czechoslovakian, grossing, alois, heard, dtm, connecticut, links,
# Nearest to after: byzantines, had, gere, exile, july, son, morning, gains,
# Nearest to and: madhya, new, rationalization, dynasties, as, restraints, vl, zambezi,
# Nearest to first: titles, kicks, equals, franke, hulagu, rejectionist, greenland, extensive,
# Nearest to when: exquisite, will, would, went, attacked, standardise, next, was,
# Nearest to by: gladio, been, postponed, rooftops, linspire, excluding, indirection, aqaba,
# Nearest to however: iconoclasm, bono, opposition, proportionate, peace, infrastructures, nazarenes, provisions,
# Nearest to centre: located, defensa, landsat, beginnings, acadia, foothills, center, lake,
# Nearest to pre: iranic, fabrique, lesser, metaphase, culture, unbound, ukrainians, sanctification,
# Nearest to report: bismarck, review, overviews, diminished, presidency, papers, oeuvre, kiribati,
# Nearest to scale: bicyclists, terrorizing, amidst, elevation, inflation, seabed, colliding, decays,
# Nearest to powers: commanding, compromise, ilr, valeria, fiefs, insurer, rule, legislation,
# Nearest to channel: subscribers, gog, rectifier, dana, javan, lan, centipede, lexicography,
# Nearest to egypt: conquered, arab, sopra, antilles, zoroastrians, bouvines, armies, syria,
# Nearest to joseph: accuser, tippett, lachmann, distrusted, trintignant, hackman, malan, decimalisation,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2754 0.4440 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1907 0.4378 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1804 0.4389 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1847 0.4379 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.1125 0.4365 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1767 0.4379 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1737 0.4381 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1718 0.4381 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.2225 0.0702 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.2000 0.4387 sec/batch
# Nearest to some: between, clinicians, semiology, neutral, exceptions, aft, bias, genealogies,
# Nearest to new: and, dtm, czechoslovakian, grossing, dupont, heard, hudd, rollercoaster,
# Nearest to after: byzantines, had, gere, exile, gains, july, veered, wait,
# Nearest to and: rationalization, new, as, madhya, often, labels, typhus, simulate,
# Nearest to first: titles, kicks, equals, franke, hulagu, goalscorer, rejectionist, guaranteeing,
# Nearest to when: exquisite, will, would, next, went, standardise, enough, await,
# Nearest to by: gladio, postponed, been, indirection, cardigan, rooftops, linspire, aqaba,
# Nearest to however: iconoclasm, scrolling, struggle, proportionate, sverdlovsk, nazarenes, bono, mutineers,
# Nearest to centre: located, defensa, landsat, beginnings, center, acadia, lake, foothills,
# Nearest to pre: iranic, fabrique, lesser, unbound, metaphase, culture, underwear, ukrainians,
# Nearest to report: bismarck, review, papers, overviews, oeuvre, links, presidency, diminished,
# Nearest to scale: bicyclists, amidst, terrorizing, colliding, taekwondo, elliptic, inflation, luxembourgish,
# Nearest to powers: commanding, compromise, ilr, valeria, fiefs, insurer, rule, cannot,
# Nearest to channel: subscribers, rectifier, dana, gog, lan, javan, serial, lexicography,
# Nearest to egypt: conquered, sopra, arab, zoroastrians, antilles, bouvines, syria, ottoman,
# Nearest to joseph: accuser, tippett, lachmann, trintignant, distrusted, malan, hackman, decimalisation,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.1355 0.4426 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.1344 0.4370 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.1631 0.4390 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.1003 0.4381 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.1288 0.4396 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.1212 0.4394 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.1501 0.4397 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.1419 0.4392 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1501 0.4402 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.1128 0.4367 sec/batch
# Nearest to some: between, semiology, clinicians, may, theists, neutral, exceptions, bias,
# Nearest to new: and, czechoslovakian, dtm, heard, grossing, taxable, connecticut, afips,
# Nearest to after: byzantines, had, gere, exile, july, wait, later, once,
# Nearest to and: rationalization, madhya, new, as, dynasties, toward, zambezi, labels,
# Nearest to first: titles, kicks, equals, franke, radius, hulagu, proves, goalscorer,
# Nearest to when: exquisite, will, would, next, enough, went, was, they,
# Nearest to by: postponed, gladio, been, linspire, indirection, rooftops, aqaba, ratifying,
# Nearest to however: iconoclasm, proportionate, indicates, bono, nazarenes, metabolites, struggle, opposition,
# Nearest to centre: located, defensa, landsat, beginnings, center, street, lake, urim,
# Nearest to pre: iranic, fabrique, lesser, unbound, culture, ukrainians, sanctification, metaphase,
# Nearest to report: bismarck, papers, review, overviews, links, placards, presidency, extent,
# Nearest to scale: amidst, terrorizing, bicyclists, taekwondo, inflation, luxembourgish, decays, colliding,
# Nearest to powers: ilr, commanding, compromise, valeria, sihanouk, fiefs, rule, cannot,
# Nearest to channel: rectifier, subscribers, serial, javan, centipede, gog, dana, lan,
# Nearest to egypt: conquered, sopra, arab, zoroastrians, bouvines, ramayana, ruler, armies,
# Nearest to joseph: tippett, accuser, lachmann, trintignant, distrusted, malan, decimalisation, webmuseum,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0786 0.4448 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0895 0.4373 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0817 0.4373 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.1198 0.4397 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.1209 0.4483 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.1215 0.4372 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.1329 0.4374 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1386 0.4389 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.1072 0.4370 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.1029 0.4381 sec/batch
# Nearest to some: between, clinicians, may, neutral, genealogies, semiology, exceptions, acceptance,
# Nearest to new: and, dupont, connecticut, afips, dtm, czechoslovakian, hudd, grossing,
# Nearest to after: had, byzantines, gere, wait, july, undoing, once, gains,
# Nearest to and: rationalization, labels, new, often, as, toward, madhya, simulate,
# Nearest to first: titles, kicks, equals, franke, radius, the, proves, hulagu,
# Nearest to when: will, exquisite, would, enough, next, they, went, await,
# Nearest to by: postponed, indirection, gladio, been, linspire, rooftops, crystallographic, eigenvalue,
# Nearest to however: proportionate, indicates, iconoclasm, metabolites, deploying, bono, scrolling, nazarenes,
# Nearest to centre: located, landsat, defensa, beginnings, center, street, lake, foothills,
# Nearest to pre: iranic, fabrique, metaphase, lesser, unbound, ukrainians, culture, sanctification,
# Nearest to report: review, papers, bismarck, overviews, links, extent, agreements, directory,
# Nearest to scale: amidst, terrorizing, decays, bicyclists, inflation, taekwondo, observation, luxembourgish,
# Nearest to powers: compromise, ilr, valeria, commanding, rule, fiefs, cannot, insurer,
# Nearest to channel: subscribers, rectifier, serial, lan, dana, lexicography, centipede, javan,
# Nearest to egypt: conquered, arab, sopra, bedouin, syria, bouvines, zoroastrians, antilles,
# Nearest to joseph: tippett, accuser, lachmann, trintignant, distrusted, decimalisation, malan, permo,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0962 0.4398 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.1501 0.4359 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.1065 0.4383 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0837 0.4380 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.1093 0.4392 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0962 0.4391 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.1444 0.4363 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.1204 0.4374 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.1372 0.4381 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.1183 0.4386 sec/batch
# Nearest to some: between, may, semiology, exceptions, genealogies, acceptance, neutral, theists,
# Nearest to new: and, czechoslovakian, connecticut, dupont, dtm, taxable, afips, hudd,
# Nearest to after: had, byzantines, gere, exile, undoing, once, july, later,
# Nearest to and: rationalization, new, as, often, dynasties, madhya, toward, the,
# Nearest to first: titles, kicks, franke, equals, the, hulagu, radius, proves,
# Nearest to when: exquisite, will, would, next, went, returned, was, blessed,
# Nearest to by: gladio, been, the, linspire, formally, ratifying, emigration, rooftops,
# Nearest to however: proportionate, scrolling, indicates, iconoclasm, deploying, metabolites, disuse, tag,
# Nearest to centre: located, defensa, landsat, beginnings, center, street, rail, lake,
# Nearest to pre: iranic, fabrique, ukrainians, culture, unbound, lesser, metaphase, yao,
# Nearest to report: review, overviews, bismarck, links, papers, agreements, placards, directory,
# Nearest to scale: amidst, terrorizing, decays, bicyclists, taekwondo, observation, luxembourgish, inflation,
# Nearest to powers: compromise, rule, commanding, ilr, fiefs, legislation, valeria, insurer,
# Nearest to channel: subscribers, rectifier, lan, serial, lexicography, dana, javan, centipede,
# Nearest to egypt: conquered, arab, sopra, bedouin, syria, zoroastrians, levant, egyptian,
# Nearest to joseph: tippett, accuser, trintignant, lachmann, distrusted, webmuseum, permo, malan,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.1043 0.4448 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0804 0.4378 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0854 0.4378 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.1103 0.4398 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.1113 0.4374 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1741 0.4374 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.2000 0.4390 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.1107 0.4378 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0721 0.4370 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.1190 0.4389 sec/batch
# Nearest to some: between, exceptions, may, semiology, genealogies, neutral, conversions, clinicians,
# Nearest to new: and, czechoslovakian, dtm, dupont, connecticut, heard, hudd, afips,
# Nearest to after: had, gere, byzantines, once, undoing, july, exile, later,
# Nearest to and: new, dynasties, as, labels, madhya, rationalization, toward, often,
# Nearest to first: titles, franke, kicks, hulagu, goalscorer, radius, equals, entire,
# Nearest to when: exquisite, went, returned, blessed, will, would, was, next,
# Nearest to by: gladio, linspire, been, postponed, showdown, formally, emigration, aqaba,
# Nearest to however: proportionate, indicates, iconoclasm, escalating, nazarenes, scrolling, disuse, mediator,
# Nearest to centre: landsat, located, defensa, beginnings, center, street, urim, lake,
# Nearest to pre: iranic, fabrique, ukrainians, culture, metaphase, lesser, unbound, mestre,
# Nearest to report: papers, review, overviews, links, bismarck, placards, agreements, lieberman,
# Nearest to scale: amidst, terrorizing, observation, bicyclists, taekwondo, inflation, luxembourgish, bombardier,
# Nearest to powers: cannot, compromise, fiefs, ilr, commanding, valeria, insurer, rule,
# Nearest to channel: subscribers, rectifier, lan, serial, centipede, cobol, pbs, javan,
# Nearest to egypt: conquered, arab, bedouin, sopra, bouvines, ramayana, syria, zoroastrians,
# Nearest to joseph: tippett, accuser, lachmann, trintignant, distrusted, webmuseum, permo, malan,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 4.0070 0.4423 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0684 0.4372 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0921 0.4374 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0626 0.4380 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.1067 0.4384 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0973 0.3856 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0659 0.4387 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 4.0327 0.4386 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0678 0.4389 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 4.0527 0.4368 sec/batch
# Nearest to some: between, may, conversions, semiology, exceptions, theists, often, clinicians,
# Nearest to new: and, dupont, dtm, taxable, czechoslovakian, afips, connecticut, cyc,
# Nearest to after: byzantines, gere, had, son, wooing, july, undoing, later,
# Nearest to and: new, labels, often, dynasties, as, madhya, rationalization, contended,
# Nearest to first: titles, franke, kicks, the, equals, radius, hulagu, goalscorer,
# Nearest to when: exquisite, was, blessed, went, returned, next, will, would,
# Nearest to by: been, the, indirection, tutelary, gladio, showdown, linspire, transcribing,
# Nearest to however: indicates, proportionate, metabolites, scrolling, ethers, disuse, iconoclasm, mediator,
# Nearest to centre: located, landsat, defensa, beginnings, center, street, lake, urim,
# Nearest to pre: iranic, fabrique, culture, ukrainians, mestre, lesser, unbound, sanctification,
# Nearest to report: review, papers, links, overviews, placards, bismarck, lieberman, agreements,
# Nearest to scale: amidst, observation, terrorizing, taekwondo, bicyclists, decays, luxembourgish, bombardier,
# Nearest to powers: cannot, commanding, compromise, valeria, ilr, fiefs, rule, insurer,
# Nearest to channel: subscribers, rectifier, lan, serial, centipede, stations, commuters, pbs,
# Nearest to egypt: conquered, arab, bedouin, sopra, ramayana, hassan, zoroastrians, levant,
# Nearest to joseph: tippett, accuser, trintignant, lachmann, webmuseum, distrusted, permo, malan,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0587 0.4428 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 4.0158 0.4375 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0578 0.4398 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0907 0.4380 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0745 0.4460 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0547 0.4404 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9813 0.4388 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 4.0022 0.4379 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 4.0007 0.4393 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 4.0008 0.4401 sec/batch
# Nearest to some: between, may, theists, conversions, clinicians, often, semiology, exceptions,
# Nearest to new: and, connecticut, dupont, dtm, czechoslovakian, cyc, taxable, afips,
# Nearest to after: byzantines, gere, had, gains, wait, wooing, undoing, once,
# Nearest to and: new, madhya, zambezi, as, often, rationalization, dynasties, toward,
# Nearest to first: titles, kicks, franke, the, radius, equals, entire, substitutions,
# Nearest to when: went, was, exquisite, will, returned, would, next, blessed,
# Nearest to by: the, been, postponed, showdown, gladio, linspire, noaa, eigenvalue,
# Nearest to however: proportionate, metabolites, indicates, escalating, mediator, deploying, scrolling, disuse,
# Nearest to centre: landsat, located, defensa, beginnings, center, street, lake, terminus,
# Nearest to pre: iranic, fabrique, mestre, culture, ukrainians, unbound, yao, lesser,
# Nearest to report: papers, review, overviews, links, agreements, placards, bismarck, darfur,
# Nearest to scale: amidst, terrorizing, taekwondo, observation, luxembourgish, decays, bombardier, inflation,
# Nearest to powers: compromise, ilr, cannot, commanding, fiefs, valeria, insurer, rule,
# Nearest to channel: subscribers, rectifier, lan, pbs, centipede, commuters, serial, stations,
# Nearest to egypt: conquered, arab, bedouin, hassan, sopra, ramayana, levant, zoroastrians,
# Nearest to joseph: accuser, tippett, distrusted, trintignant, lachmann, webmuseum, permo, pinsent,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0306 0.4445 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0515 0.4376 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9820 0.4388 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0907 0.4390 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0754 0.4351 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 4.0290 0.4386 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0424 0.4388 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0603 0.4386 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0244 0.4371 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0357 0.4381 sec/batch
# Nearest to some: between, may, conversions, clinicians, exceptions, theists, often, headship,
# Nearest to new: and, connecticut, dupont, cyc, bruins, ordaining, york, dtm,
# Nearest to after: gere, had, byzantines, july, wooing, undoing, gains, once,
# Nearest to and: new, labels, as, the, often, not, rationalization, eigenstate,
# Nearest to first: titles, the, franke, kicks, radius, equals, entire, schechter,
# Nearest to when: will, exquisite, went, next, returned, blessed, was, would,
# Nearest to by: the, been, gladio, postponed, showdown, lder, linspire, indirection,
# Nearest to however: proportionate, indicates, metabolites, disuse, expressive, scrolling, deploying, ethers,
# Nearest to centre: landsat, located, defensa, beginnings, center, street, municipal, terminus,
# Nearest to pre: iranic, fabrique, mestre, metaphase, unbound, ukrainians, culture, edicule,
# Nearest to report: links, overviews, papers, review, placards, agreements, bismarck, directory,
# Nearest to scale: amidst, terrorizing, observation, taekwondo, decays, luxembourgish, bombardier, bicyclists,
# Nearest to powers: ilr, cannot, compromise, fiefs, insurer, commanding, rule, valeria,
# Nearest to channel: subscribers, rectifier, stations, pbs, lan, affiliate, skynyrd, commuters,
# Nearest to egypt: arab, bedouin, conquered, hassan, egyptian, sopra, ramayana, sahara,
# Nearest to joseph: tippett, accuser, trintignant, lachmann, webmuseum, distrusted, malan, permo,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0431 0.4439 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 4.0492 0.4384 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 4.0362 0.4394 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0579 0.4378 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0354 0.4411 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0545 0.4382 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 4.0191 0.4369 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9968 0.4381 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 4.0284 0.4376 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0748 0.4375 sec/batch
# Nearest to some: between, and, conversions, may, the, acceptance, often, almanacs,
# Nearest to new: and, connecticut, ordaining, cyc, taxable, dupont, labels, by,
# Nearest to after: had, gere, byzantines, undoing, july, shelling, once, wooing,
# Nearest to and: the, madhya, as, new, of, zambezi, some, often,
# Nearest to first: titles, franke, the, entire, kicks, equals, radius, schechter,
# Nearest to when: went, returned, will, was, blessed, next, exquisite, would,
# Nearest to by: the, been, lder, gladio, of, system, showdown, new,
# Nearest to however: proportionate, indicates, escalating, disuse, mediator, have, as, metabolites,
# Nearest to centre: landsat, defensa, located, beginnings, center, street, municipal, terminus,
# Nearest to pre: iranic, fabrique, mestre, culture, ukrainians, edicule, societies, yao,
# Nearest to report: links, overviews, review, papers, placards, agreements, directory, darfur,
# Nearest to scale: amidst, terrorizing, bicyclists, observation, luxembourgish, taekwondo, bombardier, decays,
# ...
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.7854 0.4454 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.8399 0.4453 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8878 0.4468 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8897 0.4462 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8549 0.4459 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.9103 0.4461 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9662 0.4451 sec/batch
# Nearest to some: are, and, which, not, as, have, among, that,
# Nearest to new: york, cyc, bruins, commerzbank, press, connecticut, carolina, bandleaders,
# Nearest to after: during, had, later, was, before, with, in, the,
# Nearest to and: the, of, as, with, a, in, which, some,
# Nearest to first: the, in, titles, franke, a, entire, of, before,
# Nearest to when: went, returned, before, up, was, next, would, so,
# Nearest to by: the, of, been, from, second, and, in, a,
# Nearest to however: metabolites, ethers, it, have, converted, as, some, degenerated,
# Nearest to centre: defensa, landsat, located, bristol, futuristic, street, tower, terminus,
# Nearest to pre: mestre, fabrique, culture, iranic, scandinavia, edicule, simchat, columbian,
# Nearest to report: september, pdf, reports, overviews, news, investigation, lieberman, review,
# Nearest to scale: observation, scales, octave, indonesian, regime, euphonium, bowed, percussive,
# Nearest to powers: cannot, horthy, exercised, zablocki, adjudication, treaties, mandelson, insurer,
# Nearest to channel: stations, channels, pbs, subscribers, affiliate, broadcasting, broadcast, commuters,
# Nearest to egypt: cairo, egyptian, levant, governorate, arab, luxor, sahara, syria,
# Nearest to joseph: kinsella, tippett, lachmann, prevenient, webmuseum, layton, accuser, levi,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8659 0.4513 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8498 0.4461 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.9105 0.4464 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8727 0.4542 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8602 0.4460 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8797 0.4470 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8727 0.4462 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8596 0.4468 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.9124 0.4481 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8687 0.4464 sec/batch
# Nearest to some: and, which, as, are, among, between, the, many,
# Nearest to new: york, cyc, as, by, commerzbank, nijhoff, arbor, carolina,
# Nearest to after: during, had, later, was, remained, in, the, before,
# Nearest to and: of, the, as, with, in, a, some, which,
# Nearest to first: the, in, titles, entire, franke, second, schechter, of,
# Nearest to when: went, returned, before, up, would, was, spent, so,
# Nearest to by: the, of, from, and, in, been, second, but,
# Nearest to however: metabolites, ethers, have, it, some, as, converted, to,
# Nearest to centre: defensa, landsat, bristol, futuristic, located, street, kpa, lingo,
# Nearest to pre: mestre, fabrique, culture, iranic, columbian, scandinavia, edicule, valdemar,
# Nearest to report: september, pdf, overviews, reports, news, lieberman, review, investigation,
# Nearest to scale: observation, scales, indonesian, octave, bowed, regime, euphonium, astronomical,
# Nearest to powers: cannot, exercised, retains, vested, treaties, horthy, adjudication, mandelson,
# Nearest to channel: channels, stations, pbs, subscribers, affiliate, broadcasting, broadcast, commuters,
# Nearest to egypt: cairo, egyptian, levant, arab, governorate, luxor, prick, sahara,
# Nearest to joseph: kinsella, tippett, webmuseum, lachmann, layton, prevenient, accuser, levi,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8704 0.4477 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8789 0.4443 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8283 0.4445 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8395 0.4448 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8911 0.4454 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8963 0.4439 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9776 0.4445 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9560 0.4454 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9600 0.4428 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8426 0.4446 sec/batch
# Nearest to some: and, which, are, between, among, many, not, as,
# Nearest to new: york, in, as, cyc, by, spring, commerzbank, arbor,
# Nearest to after: during, later, was, had, in, the, remained, with,
# Nearest to and: of, the, as, in, with, a, to, by,
# Nearest to first: the, in, franke, schechter, entire, titles, second, made,
# Nearest to when: went, returned, was, up, spent, before, but, would,
# Nearest to by: the, of, from, and, in, been, second, to,
# Nearest to however: it, as, metabolites, have, ethers, proportionate, some, to,
# Nearest to centre: landsat, defensa, bristol, located, futuristic, inclination, globus, kpa,
# Nearest to pre: fabrique, culture, mestre, iranic, columbian, th, edicule, scandinavia,
# Nearest to report: september, reports, pdf, overviews, news, lieberman, investigation, bias,
# Nearest to scale: observation, scales, indonesian, regime, bukharin, octave, bowed, harmonicist,
# Nearest to powers: cannot, exercised, retains, treaties, horthy, zablocki, vested, mandelson,
# Nearest to channel: channels, stations, pbs, subscribers, affiliate, broadcasting, broadcast, commuters,
# Nearest to egypt: cairo, egyptian, levant, governorate, luxor, arab, gaza, sahara,
# Nearest to joseph: tippett, kinsella, accuser, layton, lachmann, webmuseum, prevenient, levi,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8247 0.4517 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.9057 0.4463 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7982 0.4475 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8703 0.4467 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8610 0.4488 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8339 0.4457 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9460 0.2136 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8476 0.4465 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8596 0.4461 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8457 0.4448 sec/batch
# Nearest to some: which, are, between, among, and, that, less, have,
# Nearest to new: york, in, cyc, spring, commerzbank, carolina, press, announced,
# Nearest to after: during, was, later, had, the, in, with, before,
# Nearest to and: of, the, as, in, with, a, by, many,
# Nearest to first: the, in, entire, schechter, of, second, franke, before,
# Nearest to when: went, returned, was, before, to, so, but, up,
# Nearest to by: the, of, in, and, from, second, been, but,
# Nearest to however: have, metabolites, it, some, ethers, as, converted, less,
# Nearest to centre: defensa, bristol, located, landsat, street, futuristic, tower, heritage,
# Nearest to pre: fabrique, mestre, culture, iranic, columbian, valdemar, edicule, simchat,
# Nearest to report: lieberman, september, reports, bias, pdf, news, investigation, overviews,
# Nearest to scale: scales, observation, octave, bowed, indonesian, tuning, euphonium, values,
# Nearest to powers: cannot, exercised, retains, zablocki, treaties, horthy, mandelson, vested,
# Nearest to channel: channels, stations, pbs, affiliate, subscribers, broadcasting, broadcast, commuters,
# Nearest to egypt: cairo, egyptian, levant, governorate, luxor, arab, sahara, harburg,
# Nearest to joseph: kinsella, tippett, webmuseum, accuser, layton, lachmann, prevenient, levi,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8385 0.4528 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8418 0.4468 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8524 0.4465 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8464 0.4454 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.9057 0.4444 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8772 0.4474 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8898 0.4461 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7884 0.4443 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8390 0.4455 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8428 0.4445 sec/batch
# Nearest to some: which, are, not, and, as, that, have, a,
# Nearest to new: york, in, spring, by, cyc, commerzbank, as, announced,
# Nearest to after: was, during, later, had, before, in, the, with,
# Nearest to and: of, the, as, with, in, a, for, by,
# Nearest to first: the, in, a, second, entire, before, of, was,
# Nearest to when: went, before, returned, immediately, to, was, up, but,
# Nearest to by: the, of, in, and, from, been, second, which,
# Nearest to however: it, have, metabolites, as, ethers, disuse, some, converted,
# Nearest to centre: defensa, bristol, landsat, street, located, ensign, futuristic, globus,
# Nearest to pre: fabrique, columbian, culture, mestre, iranic, valdemar, scandinavia, edicule,
# Nearest to report: reports, lieberman, pdf, overviews, bias, news, september, investigation,
# Nearest to scale: scales, observation, regime, indonesian, octave, bukharin, euphonium, bowed,
# Nearest to powers: cannot, zablocki, exercised, treaties, mandelson, retains, horthy, tambo,
# Nearest to channel: channels, pbs, stations, subscribers, affiliate, broadcasting, broadcast, commuters,
# Nearest to egypt: cairo, egyptian, levant, governorate, luxor, arab, syria, sahara,
# Nearest to joseph: kinsella, prevenient, accuser, levi, lachmann, webmuseum, fingerprints, layton,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7666 0.4500 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8563 0.4450 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8432 0.4434 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8482 0.4455 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8366 0.4444 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9316 0.4544 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8670 0.4465 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8424 0.4454 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8523 0.4458 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8816 0.4448 sec/batch
# Nearest to some: which, are, and, not, have, as, that, among,
# Nearest to new: york, in, spring, cyc, carolina, as, press, by,
# Nearest to after: later, during, had, was, before, the, in, remained,
# Nearest to and: as, of, the, with, in, a, which, by,
# Nearest to first: the, in, a, second, of, before, entire, was,
# Nearest to when: went, to, before, returned, so, enough, but, up,
# Nearest to by: the, of, and, in, from, which, been, second,
# Nearest to however: have, it, as, metabolites, to, disuse, some, although,
# Nearest to centre: defensa, bristol, landsat, located, street, globus, futuristic, felsic,
# Nearest to pre: fabrique, mestre, columbian, valdemar, culture, philoponus, iranic, simchat,
# Nearest to report: reports, lieberman, pdf, news, overviews, september, bias, review,
# Nearest to scale: observation, scales, indonesian, regime, bowed, octave, bukharin, euphonium,
# Nearest to powers: cannot, exercised, retains, treaties, zablocki, horthy, vested, mandelson,
# Nearest to channel: channels, stations, pbs, subscribers, affiliate, broadcasting, broadcast, networks,
# Nearest to egypt: cairo, egyptian, luxor, governorate, levant, arab, sahara, cosmetic,
# Nearest to joseph: kinsella, webmuseum, prevenient, tippett, accuser, lachmann, formalisms, l,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8944 0.4491 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8180 0.4451 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8305 0.4434 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8820 0.4444 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.9020 0.4460 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8751 0.4458 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8400 0.4454 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8791 0.4451 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8289 0.4432 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8039 0.4460 sec/batch
# Nearest to some: which, and, not, are, as, that, between, in,
# Nearest to new: york, in, cyc, by, spring, press, announced, of,
# Nearest to after: during, later, was, had, the, in, before, when,
# Nearest to and: of, as, the, with, in, which, a, for,
# Nearest to first: the, in, second, entire, a, of, schechter, was,
# Nearest to when: went, to, before, returned, the, until, was, enough,
# Nearest to by: the, of, and, from, in, which, second, been,
# Nearest to however: as, it, have, some, to, metabolites, although, the,
# Nearest to centre: defensa, bristol, landsat, globus, located, street, ensign, heritage,
# Nearest to pre: columbian, fabrique, culture, mestre, philoponus, valdemar, iranic, century,
# Nearest to report: reports, news, pdf, lieberman, overviews, bias, september, investigation,
# Nearest to scale: observation, scales, indonesian, regime, bowed, tuning, octave, euphonium,
# Nearest to powers: cannot, treaties, retains, exercised, zablocki, vested, horthy, reigns,
# Nearest to channel: channels, stations, subscribers, pbs, affiliate, broadcasting, broadcast, networks,
# Nearest to egypt: egyptian, cairo, levant, luxor, governorate, arab, sahara, syria,
# Nearest to joseph: kinsella, webmuseum, tippett, prevenient, layton, lachmann, socialists, l,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8850 0.4503 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8603 0.4459 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9453 0.4451 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9477 0.4434 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.9274 0.4437 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8863 0.4455 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.8073 0.4445 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8319 0.4443 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7510 0.4456 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8616 0.4442 sec/batch
# Nearest to some: which, not, that, and, are, often, as, many,
# Nearest to new: york, in, spring, cyc, by, as, prior, press,
# Nearest to after: during, later, was, had, remained, in, the, with,
# Nearest to and: of, as, the, with, in, a, by, for,
# Nearest to first: the, in, entire, second, schechter, a, franke, of,
# Nearest to when: went, to, returned, before, was, up, so, until,
# Nearest to by: the, of, and, from, in, s, which, second,
# Nearest to however: as, it, have, some, metabolites, although, converted, following,
# Nearest to centre: bristol, defensa, globus, landsat, located, heritage, grub, street,
# Nearest to pre: columbian, fabrique, culture, mestre, valdemar, iranic, philoponus, dating,
# Nearest to report: reports, news, lieberman, pdf, september, bias, overviews, reported,
# Nearest to scale: observation, scales, regime, bowed, tuning, indonesian, poor, octave,
# Nearest to powers: cannot, retains, zablocki, treaties, exercised, reigns, horthy, tambo,
# Nearest to channel: channels, stations, pbs, subscribers, affiliate, broadcasting, broadcast, networks,
# Nearest to egypt: cairo, egyptian, levant, luxor, governorate, arab, cosmetic, sahara,
# Nearest to joseph: kinsella, tippett, webmuseum, lachmann, accuser, layton, prevenient, fiasco,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8449 0.4509 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8500 0.4441 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
